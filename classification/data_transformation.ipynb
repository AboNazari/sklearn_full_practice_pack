# %%
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import pandas as pd

# %%
X, y = fetch_openml("titanic", version=1, return_X_y=True)
X.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      0      0   24160  211.3375       B5        S    2    NaN
# 1      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
X = pd.DataFrame(X)
X.drop(columns='name', inplace=True)

# %%
# one hot encoding
onehot = OneHotEncoder(sparse_output=False,handle_unknown="ignore")
sex_encoded = onehot.fit_transform(X[['sex']])
sex_columns = onehot.get_feature_names_out(['sex'])
sex_df = pd.DataFrame(sex_encoded, columns=sex_columns)
X_one_hot = pd.concat([X, sex_df], axis=1)
X_one_hot.drop(columns='sex', inplace=True)
X_one_hot['sex_female'] = X_one_hot['sex_female'].astype(int) 
X_one_hot['sex_male'] = X_one_hot['sex_male'].astype(int)

# %%
# bining for categorizing data
bins = [0, 12, 18, 35, 60, 120]
labels = ['Child', 'Teenager', 'Young Adult', 'Adult', 'Senior']
values = [0,1,2,3,4]
X['age cat'] = pd.cut(X['age'], bins=bins, labels=values, right=False)

X.head(30)
# Out:
#     pclass     sex      age  sibsp  parch    ticket      fare    cabin  \
# 0        1  female  29.0000      0      0     24160  211.3375       B5
# 1        1    male   0.9167      1      2    113781  151.5500  C22 C26
# 2        1  female   2.0000      1      2    113781  151.5500  C22 C26
# 3        1    male  30.0000      1      2    113781  151.5500  C22 C26
# 4        1  female  25.0000      1      2    113781  151.5500  C22 C26
# 5        1    male  48.0000      0      0     19952   26.5500      E12
# 6        1  female  63.0000      1      0     13502   77.9583       D7
# 7        1    male  39.0000      0      0    112050    0.0000      A36
# 8        1  female  53.0000      2      0     11769   51.4792     C101
# 9        1    male  71.0000      0      0  PC 17609   49.5042      NaN
# 10       1    male  47.0000      1      0  PC 17757  227.5250  C62 C64
# 11       1  female  18.0000      1      0  PC 17757  227.5250  C62 C64
# 12       1  female  24.0000      0      0  PC 17477   69.3000      B35
# 13       1  female  26.0000      0      0     19877   78.8500      NaN
# 14       1    male  80.0000      0      0     27042   30.0000      A23
# 15       1    male      NaN      0      0  PC 17318   25.9250      NaN
# 16       1    male  24.0000      0      1  PC 17558  247.5208  B58 B60
# 17       1  female  50.0000      0      1  PC 17558  247.5208  B58 B60
# 18       1  female  32.0000      0      0     11813   76.2917      D15
# 19       1    male  36.0000      0      0     13050   75.2417       C6
# 20       1    male  37.0000      1      1     11751   52.5542      D35
# 21       1  female  47.0000      1      1     11751   52.5542      D35
# 22       1    male  26.0000      0      0    111369   30.0000     C148
# 23       1  female  42.0000      0      0  PC 17757  227.5250      NaN
# 24       1  female  29.0000      0      0  PC 17483  221.7792      C97
# 25       1    male  25.0000      0      0     13905   26.0000      NaN
# 26       1    male  25.0000      1      0     11967   91.0792      B49
# 27       1  female  19.0000      1      0     11967   91.0792      B49
# 28       1  female  35.0000      0      0  PC 17760  135.6333      C99
# 29       1    male  28.0000      0      0    110564   26.5500      C52
#
#    embarked boat   body                           home.dest age cat
# 0         S    2    NaN                        St Louis, MO       2
# 1         S   11    NaN     Montreal, PQ / Chesterville, ON       0
# 2         S  NaN    NaN     Montreal, PQ / Chesterville, ON       0
# 3         S  NaN  135.0     Montreal, PQ / Chesterville, ON       2
# 4         S  NaN    NaN     Montreal, PQ / Chesterville, ON       2
# 5         S    3    NaN                        New York, NY       3
# 6         S   10    NaN                          Hudson, NY       4
# 7         S  NaN    NaN                         Belfast, NI       3
# 8         S    D    NaN                 Bayside, Queens, NY       3
# 9         C  NaN   22.0                 Montevideo, Uruguay       4
# 10        C  NaN  124.0                        New York, NY       3
# 11        C    4    NaN                        New York, NY       2
# 12        C    9    NaN                       Paris, France       2
# 13        S    6    NaN                                 NaN       2
# 14        S    B    NaN                       Hessle, Yorks       4
# 15        S  NaN    NaN                        New York, NY     NaN
# 16        C  NaN    NaN                        Montreal, PQ       2
# 17        C    6    NaN                        Montreal, PQ       3
# 18        C    8    NaN                                 NaN       2
# 19        C    A    NaN                        Winnipeg, MN       3
# 20        S    5    NaN                        New York, NY       3
# 21        S    5    NaN                        New York, NY       3
# 22        C    5    NaN                        New York, NY       2
# 23        C    4    NaN                                 NaN       3
# 24        S    8    NaN                                 NaN       2
# 25        C  NaN  148.0                   San Francisco, CA       2
# 26        C    7    NaN                        Dowagiac, MI       2
# 27        C    7    NaN                        Dowagiac, MI       2
# 28        S    8    NaN                                 NaN       3
# 29        S    D    NaN  Stockholm, Sweden / Washington, DC       2

# %%
X['cabin'] = X['cabin'].fillna("M")
X['cabin'].unique()
# Out:
# array(['B5', 'C22 C26', 'E12', 'D7', 'A36', 'C101', 'M', 'C62 C64', 'B35',
       'C23 C25 C27', 'E36', 'D34', 'D40', 'B39', 'B41', 'B102', 'C123',
       'E63', 'C130', 'B86', 'C92', 'A5', 'C51', 'B42', 'C91', 'C125',
       'D10 D12', 'B82 B84', 'E50', 'D33', 'C83', 'B94', 'D49', 'D45',
       'B69', 'B11', 'E46', 'C39', 'B18', 'D11', 'C93', 'B28', 'C49',
       'B52 B54 B56', 'E60', 'C132', 'B37', 'D21', 'D19', 'C124', 'D17',
       'B101', 'D28', 'D6', 'D9', 'B80', 'C106', 'B79', 'C47', 'D30',
       'C90', 'E38', 'C78', 'C30', 'C118', 'D36', 'D48', 'D47', 'C105',
       'B36', 'B30', 'D43', 'B24', 'C2', 'C65', 'B73', 'C104', 'C110',
       'C50', 'B3', 'A24', 'A32', 'A11', 'A10', 'B57 B59 B63 B66', 'C28',
       'E44', 'A26', 'A6', 'A7', 'C31', 'A19', 'B45', 'E34', 'B78', 'B50',
       'C87', 'C116', 'C55 C57', 'D50', 'E68', 'E67', 'C126', 'C68',
       'C70', 'C53', 'B19', 'D46', 'D37', 'D26', 'C32', 'C80', 'C82',
       'C128', 'E39 E41', 'D', 'F4', 'D56', 'F33', 'E101', 'E77', 'F2',
       'D38', 'F', 'F G63', 'F E57', 'F E46', 'F G73', 'E121', 'F E69',
       'E10', 'G6', 'F38']])
cabin_encoded = ordin_encoder.fit_transform(X[['cabin']])
X['cabin encoded'] = cabin_encoded.astype(int)
X.head(10)
# Out:
#    pclass     sex      age  sibsp  parch    ticket      fare    cabin  \
# 0       1  female  29.0000      0      0     24160  211.3375       B5
# 1       1    male   0.9167      1      2    113781  151.5500  C22 C26
# 2       1  female   2.0000      1      2    113781  151.5500  C22 C26
# 3       1    male  30.0000      1      2    113781  151.5500  C22 C26
# 4       1  female  25.0000      1      2    113781  151.5500  C22 C26
# 5       1    male  48.0000      0      0     19952   26.5500      E12
# 6       1  female  63.0000      1      0     13502   77.9583       D7
# 7       1    male  39.0000      0      0    112050    0.0000      A36
# 8       1  female  53.0000      2      0     11769   51.4792     C101
# 9       1    male  71.0000      0      0  PC 17609   49.5042        M
#
#   embarked boat   body                        home.dest age cat  cabin encoded
# 0        S    2    NaN                     St Louis, MO       2              0
# 1        S   11    NaN  Montreal, PQ / Chesterville, ON       0              1
# 2        S  NaN    NaN  Montreal, PQ / Chesterville, ON       0              1
# 3        S  NaN  135.0  Montreal, PQ / Chesterville, ON       2              1
# 4        S  NaN    NaN  Montreal, PQ / Chesterville, ON       2              1
# 5        S    3    NaN                     New York, NY       3              2
# 6        S   10    NaN                       Hudson, NY       4              3
# 7        S  NaN    NaN                      Belfast, NI       3              4
# 8        S    D    NaN              Bayside, Queens, NY       3              5
# 9        C  NaN   22.0              Montevideo, Uruguay       4              6
